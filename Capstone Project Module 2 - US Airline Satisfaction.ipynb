# %% [markdown]
# # US Airline Passenger Satisfaction

# %% [markdown]
# ## Latar Belakang
# Dalam sebuah bisnis, kepuasan pelanggan adalah aspek penting yang dapat dimanfaatkan sebagai alat untuk evaluasi dan improvisasi dari bisnis yang sudah berjalan. Dari kepuasan pelanggan tercermin apakah pelayanan yang diberikan oleh sebuah bisnis telah memenuhi ekspektasi pelanggan atau tidak. Yang selanjutnya dari data kepuasan pelanggan tersebut dapat dilakukan analisa untuk dapat menemukan akar permasalahan dari sebuah bisnis proses atau bahkan selanjutnya dapat digunakan menemukan solusi dari permasalahan tersebut guna untuk meningkatkan keuntungan dari sebuah bisnis.
#
# Data kali ini adalah terkait hasil survey kepuasan pelanggan suatu maskapai penerbangan Amerika Serikat (AS) terhadap pelayanan yang diberikan oleh maskapai yang selanjutnya akan dimanfaatkan sebagai bahan analisa untuk menemukan masalah dan solusi untuk dapat meningkatkan keuntungan dari maskapai penerbangan yang melakukan survey.

# %% [markdown]
# ## Pernyataan Masalah
# Sebuah maskapai penerbangan asal Amerika Serikat (AS) melakukan survey kepuasan pelanggan untuk mengevaluasi pelayanan yang telah dilakukan dan diberikan oleh maskapai. Survey dilakukan dengan memberikan penilaian dengan rentang nilai antara 1 (satu) hingga 5 (lima) dari masing-masing aspek pelayanan yang dinilai mempengaruhi kepuasan pelanggan, sebagai contoh  kebersihan, kenyamanan, layanan check-in, dan sebagainya. Dari data yang didapat melalui survey tersebut kemudian dilakukan analisa untuk menjawab pertanyaan sebagai berikut:
#
# 1. Apakah secara keseluruhan pelayanan yang diberikan oleh maskapai memuaskan?
# 2. Faktor apa saja dalam pelayanan maskapai yang mempengaruhi kepuasan pelannggan?
# 3. Dari faktor yang mempengaruhi tersebut, apakah pelayanan dapat dilanjutkan, ditambah/diimprovisasi, atau dieliminasi?
# 4. Rekomendasi apa saja yang dapat diberikan kepada maskapai untuk dapat meningkatkan kepuasan pelanggan?

# %% [markdown]
# ## Data
# Untuk dapat menjawab pertanyaan tersebut, digunakan data hasil survey kepuasan pelanggan yang mana dataset yang digunakan adalah dataset yang dapat diakses pada link berikut.

# %% [markdown]
# ### Data Content
# Dataset airline passengers sataisfaction berisikan informasi terkait kepuasan pelanggan/costumer terhadap pelayanan dari airline yang menyediakan jasa. Terdapat 24 kolom pada dataset, yaitu antara lain:
#   - Unnamed: 0 : Urutan nomor data
#   - id : ID unik tiap data / row / pelanggan
#   - Gender : Jenis kelamin pelanggan
#   - Customer type : Tipe loyalitas pelanggan
#   - Age : Usia palanggan
#   - Type of Travel : Jenis tujuan perjalanan
#   - Class : Kelas kursi yang diambil / digunakan pelanggun
#   - Flight Distance : Jarak tempuh perjalanan
#   - Inflight wifi service : Penilaian layanan jaringan wifi selama penerbangan
#   - Departure/Arrival time convenient : Penilaian kenyamanan (ketepatan) waktu keberangkatan dan waktu tiba
#   - Ease of Online booking : Penilaian kemudahan pemesanan / booking online
#   - Gate location : Penilaian lokasi gate
#   - Food and drink : Penilaian makanan dan minuman yang disajikan
#   - Online boarding : Penilaian boarding online
#   - Seat comfort : Penilaian kenyamanan tempat duduk
#   - Inflight entertainment : Penilaian layanan entertainment selama penerbangan
#   - On-board service : Penilaian pelayanan on-board
#   - Leg room service : Penilaian pelayanan ruang duduk / kaki
#   - Baggage handling : Penilaian handling bagasi
#   - Checkin service : Penilaian pelayanan checkin
#   - Inflight service : Penilaian pelayanan dalam penerbangan
#   - Cleanliness : Penilaian kebersihan
#   - Departure Delay in Minutes : Lama waktu delay / keterlambatan keberangkatan dalam satuan menit
#   - Arrival Delay in Minutes : Lama waktu delay / keterlambatan kedatangan dalam satuan menit
#   - Satisfaction : Nilai kepuasan pelanggan

# %% [markdown]
# ### Data Preparation
# Data preparation yang dilakukan antara lain adalah import library yang dibutuhkan dan menyiapkan dataset

# %%
# IMPORT LIBRARY

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from scipy.stats import normaltest, chi2_contingency, mannwhitneyu, ttest_ind

# %%
#IMPORT DATASET

airline = pd.read_csv('airline passanger satisfaction.csv')
pd.set_option('display.max_columns', None)
airline
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
# ...

# %% [markdown]
# ### Data Understanding and Cleaning
# Pada tahap ini dilakukan pemahaman mendalam tentang dataset yang digunakan, seperti menemukan anomali, error, inkonsistensi data, data error dan lainnya yang kemudian akan dilakukan perapihan/pembersihan data sehingga data dapat menunjukkan hasil analisa yang lebih akurat.

# %% [markdown]
# #### a. Melihat bentuk dataset

# %%
baris, kolom = airline.shape
print (f'Dataset memiliki {baris} baris dan {kolom} kolom')
# Out:
# Dataset memiliki 103904 baris dan 25 kolom

# %% [markdown]
# #### b. Melihat datatype dan jumlah data masing-masing kolom

# %%
airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %% [markdown]
# #### c. Menampilkan statistik deskriptif dari dataset

# %%
display(airline.describe(), airline.describe(include='object'))
# Out:
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# ...

# %% [markdown]
# *Catatan* : Kolom "Unnamed" dan "id" pada statistik deskriptif tidak digunakan dalam analisa karena tidak mencerminkan data namun hanya sebagai index baris dan id penumpang/customer. Untuk selanjutnya kedua kolom tersebut akan dihapus jika tidak dibutuhkan

# %% [markdown]
# #### d. Mengecek duplikasi data pada dataset
# Acuan yang digunakan adalah "id" sebagai primary-key dari data-set yang mencerminkan masing-masing penumpang/customer

# %%
data_duplikat = airline['id'].duplicated().sum()
print (f'Data duplikat dari dataset adalah sejumlah {data_duplikat} data.')
# Out:
# Data duplikat dari dataset adalah sejumlah 0 data.

# %% [markdown]
# Tidak ditemukan data duplikat

# %% [markdown]
# #### e. Menampilkan data unik masing-masing kolom
# Untuk mengetahui variansi data pada kolom

# %%
pd.set_option('display.max_colwidth', None)

listItem = []
for col in airline.columns :
    listItem.append( [col, airline[col].nunique(), airline[col].unique()])

uniqueValue = pd.DataFrame(columns=['Column Name', 'Number of Unique', 'Unique Sample'],
                     data=listItem)
uniqueValue
# Out:
#                           Column Name  Number of Unique  \
# 0                          Unnamed: 0            103904
# 1                                  id            103904
# 2                              Gender                 2
# 3                       Customer Type                 2
# 4                                 Age                75
# 5                      Type of Travel                 2
# 6                               Class                 3
# 7                     Flight Distance              3802
# 8               Inflight wifi service                 6
# 9   Departure/Arrival time convenient                 6
# 10             Ease of Online booking                 6
# 11                      Gate location                 6
# 12                     Food and drink                 6
# 13                    Online boarding                 6
# 14                       Seat comfort                 6
# 15             Inflight entertainment                 6
# ...

# %% [markdown]
# Berikut poin-poin yang dapat diambil dari variansi data diatas:
# 1. Pada beberapa parameter penilaian seharusnya terisi dengan rentang nilai 1 (satu) hingga 5 (lima), namun terdapat angka 0 pada sebagian besar parameter, sehingga dianggap angka 0 adalah costumer / responden tidak mengisi survey untuk parameter tersbut atau pelayanan tidak tersedia/tidak relevan
# 2. Penilaian akhir kepuasan yaitu pada kolom "satisfaction" hanya memiliki 2 kategori yaitu: 1. Neutral or dissatisfied; 2. Satisfied
# 3. Tidak ditemukan adanya kesalahan penulisan / perbedaan karakter

# %% [markdown]
# ### Missing Value
# Pada tahap ini dilakukan identifikasi terhadap missing value / data kosong, yang kemudian akan dilakukan manipulasi data terhadap missing value tersebut sesuai dengan karakteristiknya agar dataset dapat menampilkan hasil analisa secara lebih akurat

# %% [markdown]
# #### a. Identifikasi Kolom dengan Missing Value

# %%
airline.isna().sum()
# Out:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# ...

# %% [markdown]
# Data kosong pada dataset hanya terdapat pada kolom "Arrival Delay in Minutes" (Durasi waktu dalay kedatangan dalam menit) yaitu sebanyak 310 data dari total data sebanyak 103904 data

# %%
persentase_missingvalue = airline['Arrival Delay in Minutes'].isna().sum()/airline.shape[0]*100
print (f'Persentase missing value dari kolom "Arrival Delay in Minutes" adalah {persentase_missingvalue}%')
# Out:
# Persentase missing value dari kolom "Arrival Delay in Minutes" adalah 0.29835232522328303%

# %% [markdown]
# Persentase dari missing value untuk kolom "Arrival Delay in Minutes" adalah sebesar 0.298 % sehingga cukup kecil dari keseluruhan jumlah data.

# %%
airline[airline.isna().any(axis=1)]
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 213            213   49608  Female     Loyal Customer   38  Business travel
# 1124          1124   73442    Male     Loyal Customer   53  Personal Travel
# 1529          1529   71178    Male     Loyal Customer   39  Business travel
# 2004          2004   72940  Female  disloyal Customer   26  Business travel
# 2108          2108  116374  Female     Loyal Customer   24  Personal Travel
# ...            ...     ...     ...                ...  ...              ...
# 102067      102067   36729    Male     Loyal Customer   49  Personal Travel
# 102384      102384   71241    Male     Loyal Customer   58  Business travel
# 102552      102552   27684  Female  disloyal Customer   29  Business travel
# 102960      102960   36787    Male     Loyal Customer   58  Business travel
# 103540      103540   45022  Female     Loyal Customer   33  Personal Travel
#
# ...

# %%
display(airline[['Departure Delay in Minutes','Arrival Delay in Minutes']].describe())
# Out:
#        Departure Delay in Minutes  Arrival Delay in Minutes
# count               103904.000000             103594.000000
# mean                    14.815618                 15.178678
# std                     38.230901                 38.698682
# min                      0.000000                  0.000000
# 25%                      0.000000                  0.000000
# 50%                      0.000000                  0.000000
# 75%                     12.000000                 13.000000
# max                   1592.000000               1584.000000

# %% [markdown]
# Berdasarkan pengamatan missing value pada kolom "Arrival Delay in Minutes" diketahui bahwa missing value bertipe MCAR (Missing Completely At Random) atau tidak ditemukannya pola pada missing value dan tidak ada hubungan antara missing value pada kolom tersebut dengan kolom-kolom lainnya. Arrival Delay in Minutes atau waktu keterlambatan kedatangan pesawat dalam satuan waktu merupakan data lamanya waktu dalam satuan menit delay/keterlambatan landing pesawat. Hal ini seharusnya terkait erat dengan Departure Delay in Minutes yang mana adalah waktu keterlambatan keberangkatan pesawat yang secara logika jika pesawat terlambat berangkat maka seharusnya pesawat juga terlambat landing/tiba. Dikuatkan juga oleh parameter statistika deskriptif untuk kedua kolom memiliki nilai yang mirip Sebagai contoh:
# - Mean sekitar 15 menit
# - Standar dev. sekitar 38 menit
# - Median 0 menit
# - Min. value 0 menit
# - Max. value sekitar 1590 menit
#
# Untuk lebih membuktikan hal tersebut maka dilakukan uji korelasi antara kedua kolom data.

# %% [markdown]
# #### b. Uji Normalitas

# %% [markdown]
# Sebelum menganalisa uji korelasi antara 2 data tersebut, terlebih dahulu dilakukan uji normalitas data.

# %%
sns.boxplot(x = airline['Departure Delay in Minutes'])
plt.title('Boxplot Departure Delay in Minutes')
plt.show()

# %% [markdown]
# Berdasarkan uji normalitas dengan metode plotting dengan boxplot, diketahui bahwa data Departure Delay in Minutes memiliki distribusi data yang tidak normal, dibuktikan dengan box plot yang menunjukkan data banyak terkonsentrasi pada waktu sekitar 0 menit, pola semacam ini juga dikenal sebagai positively skewed distribution. Selain itu dapat dilihat juga banyaknya data outlier diluar Q3 data

# %%
sns.boxplot(x = airline['Arrival Delay in Minutes'])
plt.title('Boxplot Arrival Delay in Minutes')
plt.show()

# %% [markdown]
# Berdasarkan uji normalitas dengan metode plotting dengan boxplot, diketahui bahwa data Arrival Delay in Minutes memiliki distribusi data yang tidak normal, dibuktikan dengan box plot yang menunjukkan data banyak terkonsentrasi pada waktu sekitar 0 menit, pola semacam ini juga dikenal sebagai positively skewed distribution. Selain itu dapat dilihat juga banyaknya data outlier diluar Q3 data

# %%
normality_departure_delay = normaltest(airline['Departure Delay in Minutes'])
normality_arrival_delay = normaltest(airline['Arrival Delay in Minutes'])

if normality_departure_delay[1] <= 0.05 :
    print('Data Departure Delay in Minutes tidak terdistribusi normal')
else:
    print('Data Departure Delay in Minutes terdistribusi normal')

if normality_arrival_delay[1] <= 0.05 :
    print('Data Arrival Delay in Minutes tidak terdistribusi normal')
else:
    print('Data Arrival Delay in Minutes terdistribusi normal')
# Out:
# Data Departure Delay in Minutes tidak terdistribusi normal
# Data Arrival Delay in Minutes terdistribusi normal

# %% [markdown]
# Normality test pada data Departure Delay in Minutes dan Arrival Delay in Minutes dilakukan dengan scipy.stats dengan menggunakan metode normaltest karena ukuran sampel lebih dari 5000. Setelah dilakukan plotting dan perhitungan uji normality diketahui bahwa kedua data memiliki distribusi data yang tidak normal, yang mana keduanya memiliki pola positif skewed.

# %% [markdown]
# #### c. Uji Korelasi

# %%
airline[['Departure Delay in Minutes','Arrival Delay in Minutes']].corr('spearman')
# Out:
#                             Departure Delay in Minutes  \
# Departure Delay in Minutes                    1.000000
# Arrival Delay in Minutes                      0.740843
#
#                             Arrival Delay in Minutes
# Departure Delay in Minutes                  0.740843
# Arrival Delay in Minutes                    1.000000

# %% [markdown]
# Berdasarkan correlation test didapatkan bahwa korelasi antara Departure Delay in Minutes dan Arrival Delay in Minutes adalah bernilai 0.74 atau berkorelasi kuat. Sehingga untuk data Arrival Delay in Minutes yang mana memiliki missing value tidak digunakan untuk analisa melainkan cukup menggunakan Departure Delay in Minutes dengan asumsi berdasarkan hasil korelasi adalah jika terdapat departure delay maka juga akan terjadi arrival delay dengan durasi yang sama

# %%
airline.drop('Arrival Delay in Minutes',axis=1,inplace=True)
airline.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                  4                       3              1
# ...

# %%
display(airline.head(), airline.tail())
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                  4                       3              1
# ...

# %% [markdown]
# Berikut beberapa kesimpulan yang dapat diambil dari data understanding dan data cleanign untuk data diatas:
# - Dataset memiliki 103904 baris dan 25 kolom
# - Berdasarkan kolom ID yang kita gunakan sebagai key value dari data diketahui data memiliki nilai unik sejumlah 103904 atau dapat dikatakan bahwa tidak ditemukan data duplikat
# - Penilaian untuk masing-masing aspek rating adalah pada rentang 1(buruk) sampai dengan 5(baik). Hampir keseluruhan aspek rating memiliki nilai 0, yang mana nilai 0 tidak termasuk range penilaian sehingga diasumsikan responden tidak mengisi kolom / tidak menilai pada aspek tersebut.
# - Pada kolom Satisfaction, kepuasan pelanggan dibagi menjadi 2 kategori yaitu penumpang netral atau tidak puas dan penumpang yang puas.
# - Dari total 103904 terdapat missing value pada kolom Arrival Delay in Minutes sebanyak 310 data. Data ini dinilai memiliki keterkaitan dengan kolom data Departure Delay in Minutes karena secara logika jika keberangkatan terlambat maka jam tiba juga akan terlambat. Sehingga dilakukan uji korelasi antara kedua kolom data sehingga ditemukan bahwa kedua data memiliki parameter yang mirip serta korelasi yang kuat. Selanjutnya kolom Arrival Delay in Minutes tidak digunakan (dihapus) dan sebagai evaluasi data yang digunakan hanya cukup data Departure Delay in Minutes untuk merepresentasikan juga terkait data Arrival Delay in Minutes.

# %% [markdown]
# ### Function Bantuan

# %% [markdown]
# Berikut ini kumpulan function untuk membantu melakukan kode yang dilakukan berulang pada program ini:

# %%
#function countplot 
def countplot(df, x_axis, classification = None, ):
    plt.style.use('bmh')
    sns.countplot(data = df, x = x_axis, hue = classification)

# %%
#function pieplot (Single)
def pie(df, axis, label_a, label_b):
    plt.style.use('bmh')
    plt.pie(df[axis].value_counts(), 
            labels=[label_a,label_b],
            autopct='%.2f%%',
            explode=(0.02,0.02))

# %%
#fuction pieplot (Segment)
def pieplot_by_Segment(df, segment, detail_segment, satisfaction, label_a, label_b):
    plt.pie(df[df[segment] == detail_segment][satisfaction].value_counts(), 
            labels=[label_a,label_b],
            autopct='%.2f%%',
            explode=(0.02,0.02))

# %%
def proporsi_kepuasan(df, segment, satisfaction):

    jumlah = pd.crosstab(df[segment],df[satisfaction])
    jumlah.rename(columns = {'neutral or dissatisfied' : 'Count Neutral or Dissatisfied','satisfied' : 'Count Satisfied'}, inplace = True)
    jumlah['Total'] = jumlah['Count Neutral or Dissatisfied'] + jumlah['Count Satisfied']

    persen = pd.crosstab(df[segment],df[satisfaction],normalize='index').round(4)*100
    persen.rename(columns = {'neutral or dissatisfied' : '% Neutral or Dissatisfied','satisfied' : '% Satisfied'}, inplace = True)
    persen['% Total'] = persen['% Neutral or Dissatisfied'] + persen['% Satisfied']
    
    tabel_satisfaction = pd.merge(jumlah, persen, on = segment)
    return tabel_satisfaction

# %%
def ratings_detail_per_category(df,category):
    sns.set(style='white')
    fig, axs = plt.subplots(5, 3, figsize=(20, 20))

    sns.countplot(data = df, x = category, hue ='Inflight wifi service', color='blue', ax=axs[0, 0])
    sns.countplot(data = df, x = category, hue ='Departure/Arrival time convenient', color='gold', ax=axs[0, 1])
    sns.countplot(data = df, x = category, hue ='Ease of Online booking', color='red', ax=axs[0, 2])
    sns.countplot(data = df, x = category, hue ='Gate location', color='teal', ax=axs[1, 0])
    sns.countplot(data = df, x = category, hue ='Food and drink', color='green', ax=axs[1, 1])
    sns.countplot(data = df, x = category, hue ='Online boarding', color='skyblue', ax=axs[1, 2])
    sns.countplot(data = df, x = category, hue ='Seat comfort', color='yellow', ax=axs[2, 0])
    sns.countplot(data = df, x = category, hue ='Inflight entertainment', color='pink', ax=axs[2, 1])
    sns.countplot(data = df, x = category, hue ='On-board service', color='green', ax=axs[2, 2])
    sns.countplot(data = df, x = category, hue ='Leg room service', color='red', ax=axs[3, 0])
    sns.countplot(data = df, x = category, hue ='Baggage handling', color='purple', ax=axs[3, 1])
    sns.countplot(data = df, x = category, hue ='Checkin service', color='grey', ax=axs[3, 2])
    sns.countplot(data = df, x = category, hue ='Inflight service', color='orange', ax=axs[4, 0])
    sns.countplot(data = df, x = category, hue ='Cleanliness', color='blue', ax=axs[4, 1])

# %% [markdown]
# ## Analisa Data

# %% [markdown]
# Setelah selesai melakukan data cleaning dan data understanding, kemudian dilakukan analisa terkait fitur fitur survey yang dapat mempengaruhi kepuasan dari pelanggan, yang mana kemudian dapat ditarik sebagai dasar bahan evaluasi untuk maskapai penerbangan dalam melakukan improvement dan perbaikan.

# %% [markdown]
# ### Kepuasan Pelanggan / Penumpang

# %% [markdown]
# Berdasarkan data dari statistika deskriptif sebelumnya, diketahui bahwa kolom kepuasan pelanggan berisikan 2 kategori nilai yaitu netral atau tidak puas, dan puas. Berikut detail summary datanya:

# %% [markdown]
# #### a. Proporsi overall kepuasan

# %%
airline[['satisfaction']].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    58879
# satisfied                  45025
# dtype: int64

# %%
plt.figure()
plt.suptitle('Airline Passenger Satisfaction - Overall', size = 20)

# countplot overall passenger satisfaction
plt.subplot(1,2,1)
countplot(airline, 'satisfaction')

# pieplot overall passenger satisfaction
plt.subplot(1,2,2)
pie(airline, 'satisfaction', 'Neutral or Dissatisfied', 'Satisfied')


plt.show()

# %% [markdown]
# Berdasarkan summary data kepuasan pelanggan secara overall dari 103.904 penumpang, diketahui data sebagai berikut:
# - Sebanyak 58.879 atau 56.67% penumpang menilai pengalaman terbangnya sebagai pengalaman yang NETRAL atau TIDAK MEMUASKAN
# - Sebanyak 45.025 atau 43.33% penumpang menilai pengalaman terbangnya sebagai pengalaman yang MEMUASKAN
#
# Berdasarkan summary kepuasan tersebut yang mana lebih dari separuh pelanggan menganggap perjalanannya biasa saja atau tidak memuaskan maka maskapai harus melakukan perbaikan-perbaikan guna untuk dapat memberikan kepuasan pengalaman terbang kepada pelanggan sehingga dapat mendongkrak pemasukan dari maskapai

# %% [markdown]
# #### b. Rating Fitur Penerbangan

# %%
penilaian_pelanggan = airline.drop(['Unnamed: 0','id','Gender','Customer Type','Age','Type of Travel','Class','Flight Distance'],axis=1)
penilaian_pelanggan.head()
# Out:
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  Food and drink  Online boarding  \
# 0                       3              1               5                3
# 1                       3              3               1                3
# 2                       2              2               5                5
# 3                       5              5               2                2
# 4                       3              3               4                5
#
#    Seat comfort  Inflight entertainment  On-board service  Leg room service  \
# 0             5                       5                 4                 3
# ...

# %%
ratings = penilaian_pelanggan.drop(['Departure Delay in Minutes','satisfaction'], axis=1)
ratings.head()
# Out:
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  Food and drink  Online boarding  \
# 0                       3              1               5                3
# 1                       3              3               1                3
# 2                       2              2               5                5
# 3                       5              5               2                2
# 4                       3              3               4                5
#
#    Seat comfort  Inflight entertainment  On-board service  Leg room service  \
# 0             5                       5                 4                 3
# ...

# %%
sns.set(style='white')
fig, axs = plt.subplots(5, 3, figsize=(20, 20))

sns.histplot(data = ratings, x ='Inflight wifi service', bins = 6, color='blue', ax=axs[0, 0])
sns.histplot(data = ratings, x ='Departure/Arrival time convenient', bins = 6, color='gold', ax=axs[0, 1])
sns.histplot(data = ratings, x ='Ease of Online booking', bins = 6, color='red', ax=axs[0, 2])
sns.histplot(data = ratings, x ='Gate location', bins = 6, color='teal', ax=axs[1, 0])
sns.histplot(data = ratings, x ='Food and drink', bins = 6, color='green', ax=axs[1, 1])
sns.histplot(data = ratings, x ='Online boarding', bins = 6, color='skyblue', ax=axs[1, 2])
sns.histplot(data = ratings, x ='Seat comfort', bins = 6, color='yellow', ax=axs[2, 0])
sns.histplot(data = ratings, x ='Inflight entertainment', bins = 6, color='pink', ax=axs[2, 1])
sns.histplot(data = ratings, x ='On-board service', bins = 6, color='green', ax=axs[2, 2])
sns.histplot(data = ratings, x ='Leg room service', bins = 6, color='red', ax=axs[3, 0])
sns.histplot(data = ratings, x ='Baggage handling', bins = 5, color='purple', ax=axs[3, 1])
sns.histplot(data = ratings, x ='Checkin service', bins = 6, color='grey', ax=axs[3, 2])
sns.histplot(data = ratings, x ='Inflight service', bins = 6, color='orange', ax=axs[4, 0])
sns.histplot(data = ratings, x ='Cleanliness', bins = 6, color='blue', ax=axs[4, 1])
# Out:
# <AxesSubplot:xlabel='Cleanliness', ylabel='Count'>

# %%
sns.set(style='white')
fig, axs = plt.subplots(5, 3, figsize=(20, 20))

sns.boxplot(data = ratings, x ='Inflight wifi service', color='blue', ax=axs[0, 0])
sns.boxplot(data = ratings, x ='Departure/Arrival time convenient', color='gold', ax=axs[0, 1])
sns.boxplot(data = ratings, x ='Ease of Online booking', color='red', ax=axs[0, 2])
sns.boxplot(data = ratings, x ='Gate location', color='teal', ax=axs[1, 0])
sns.boxplot(data = ratings, x ='Food and drink', color='green', ax=axs[1, 1])
sns.boxplot(data = ratings, x ='Online boarding', color='skyblue', ax=axs[1, 2])
sns.boxplot(data = ratings, x ='Seat comfort', color='yellow', ax=axs[2, 0])
sns.boxplot(data = ratings, x ='Inflight entertainment', color='pink', ax=axs[2, 1])
sns.boxplot(data = ratings, x ='On-board service', color='green', ax=axs[2, 2])
sns.boxplot(data = ratings, x ='Leg room service', color='red', ax=axs[3, 0])
sns.boxplot(data = ratings, x ='Baggage handling', color='purple', ax=axs[3, 1])
sns.boxplot(data = ratings, x ='Checkin service', color='grey', ax=axs[3, 2])
sns.boxplot(data = ratings, x ='Inflight service', color='orange', ax=axs[4, 0])
sns.boxplot(data = ratings, x ='Cleanliness', color='blue', ax=axs[4, 1])
# Out:
# <AxesSubplot:xlabel='Cleanliness'>

# %% [markdown]
# Berdasarkan masing-masing fitur survey diketahui distribusi data adalah seperti pada diagram di atas

# %% [markdown]
# ##### Overall Ratings

# %%
ratings_summary =[]
for i in ratings:
    ratings_summary.append([
        i,
        ratings[i].mean(),
        ratings[i].mode()[0]])
df_ratings_summary = pd.DataFrame(ratings_summary, columns=['Features', 'Mean', 'Mode'])
df_ratings_summary.sort_values(by='Mean', ascending=False).reset_index(drop = True)
# Out:
#                              Features      Mean  Mode
# 0                    Inflight service  3.640428     4
# 1                    Baggage handling  3.631833     4
# 2                        Seat comfort  3.439396     4
# 3                    On-board service  3.382363     4
# 4              Inflight entertainment  3.358158     4
# 5                    Leg room service  3.351055     4
# 6                     Checkin service  3.304290     4
# 7                         Cleanliness  3.286351     4
# 8                     Online boarding  3.250375     4
# 9                      Food and drink  3.202129     4
# 10  Departure/Arrival time convenient  3.060296     4
# 11                      Gate location  2.976883     3
# 12             Ease of Online booking  2.756901     3
# 13              Inflight wifi service  2.729683     3

# %%
plt.figure(figsize = (20,5))

plt.subplot(1,2,1)
sns.barplot(data = df_ratings_summary, x ='Features', y = 'Mean', palette = 'rocket')
plt.xticks(rotation = 60)
plt.title('Mean of Ratings Features')

plt.subplot(1,2,2)
sns.barplot(data = df_ratings_summary, x ='Features', y = 'Mode', palette = 'Blues_r')
plt.xticks(rotation = 60)
plt.title('Mode of Ratings Features')

plt.show()

# %% [markdown]
# Berdasarkan nilai rata-rata dan modus dari rating masing-masing fitur dari 103.904 penumpang diketahui sebagai berikut:
# - 3 fitur teratas yang memiliki nilai rata-rata dan modus tertinggi adalah:
#     - Inflight service
#     - Baggage handling
#     - Seat comfort
# - 3 fitur terbawah yang memiliki nilai rata-rata dan modus terendah adalah:
#     - Gate location
#     - Ease for online booking
#     - Inflight wifi service

# %% [markdown]
# ##### Ratings for Neutral or Dissatisfied Passengers

# %%
ratings_for_neutral = penilaian_pelanggan[penilaian_pelanggan['satisfaction'] == 'neutral or dissatisfied']
ratings_for_neutral.drop(['Departure Delay in Minutes','satisfaction'], axis = 1, inplace = True)
ratings_for_neutral.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6848\3714594698.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ratings_for_neutral.drop(['Departure Delay in Minutes','satisfaction'], axis = 1, inplace = True)
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 3                      2                                  5
# 5                      3                                  4
# 6                      2                                  4
#
#    Ease of Online booking  Gate location  Food and drink  Online boarding  \
# 0                       3              1               5                3
# ...

# %%
ratings_for_neutral_summary =[]
for i in ratings_for_neutral:
    ratings_for_neutral_summary.append([
        i,
        ratings_for_neutral[i].mean(),
        ratings_for_neutral[i].mode()[0]])
df_ratings_neutral_summary = pd.DataFrame(ratings_for_neutral_summary, columns=['Features', 'Mean', 'Mode'])
df_ratings_neutral_summary.sort_values(by=['Mean'], ascending=False).reset_index(drop = True)
# Out:
#                              Features      Mean  Mode
# 0                    Inflight service  3.388814     4
# 1                    Baggage handling  3.375991     4
# 2   Departure/Arrival time convenient  3.129112     4
# 3                     Checkin service  3.042952     3
# 4                        Seat comfort  3.036295     3
# 5                    On-board service  3.019158     3
# 6                    Leg room service  2.990812     3
# 7                       Gate location  2.976121     3
# 8                      Food and drink  2.958050     3
# 9                         Cleanliness  2.936123     3
# 10             Inflight entertainment  2.894156     3
# 11                    Online boarding  2.656125     3
# 12             Ease of Online booking  2.546850     3
# 13              Inflight wifi service  2.399633     2

# %%
plt.figure(figsize = (20,5))

plt.subplot(1,2,1)
sns.barplot(data = df_ratings_neutral_summary, x ='Features', y = 'Mean', palette = 'rocket')
plt.xticks(rotation = 60)
plt.title('Mean of Ratings Features of Neutral/Dissatisfied Cust.')

plt.subplot(1,2,2)
sns.barplot(data = df_ratings_neutral_summary, x ='Features', y = 'Mode', palette = 'Blues_r')
plt.xticks(rotation = 60)
plt.title('Mode of Ratings Features of Neutral/Dissatisfied Cust.')

plt.show()

# %% [markdown]
# Berdasarkan nilai rata-rata dan modus dari rating masing-masing fitur khusus untuk penumpang yang NETRAL atau TIDAK PUAS adalah sebagai berikut:
# - 3 fitur terbawah yang memiliki nilai rata-rata dan modus terendah adalah:
#     - Online boarding
#     - Ease for online booking
#     - Inflight wifi service
# - 3 fitur teratas yang memiliki nilai rata-rata dan modus tertinggi adalah:
#     - Inflight service
#     - Baggage handling
#     - Departure/Arrival time convenient

# %% [markdown]
# ##### Ratings for Satisfied Passengers

# %%
ratings_for_satisfied = penilaian_pelanggan[penilaian_pelanggan['satisfaction'] == 'satisfied']
ratings_for_satisfied.drop(['Departure Delay in Minutes','satisfaction'], axis = 1, inplace = True)
ratings_for_satisfied.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6848\401109800.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ratings_for_satisfied.drop(['Departure Delay in Minutes','satisfaction'], axis = 1, inplace = True)
#     Inflight wifi service  Departure/Arrival time convenient  \
# 2                       2                                  2
# 4                       3                                  3
# 7                       4                                  3
# 13                      4                                  2
# 16                      3                                  3
#
#     Ease of Online booking  Gate location  Food and drink  Online boarding  \
# 2                        2              2               5                5
# ...

# %%
ratings_for_satisfied_summary =[]
for i in ratings_for_satisfied:
    ratings_for_satisfied_summary.append([
        i,
        ratings_for_satisfied[i].mean(),
        ratings_for_satisfied[i].mode()[0]])
df_ratings_satisfied_summary = pd.DataFrame(ratings_for_satisfied_summary, columns=['Features', 'Mean', 'Mode'])
df_ratings_satisfied_summary.sort_values(by=['Mean'], ascending=False).reset_index(drop = True)
# Out:
#                              Features      Mean  Mode
# 0                     Online boarding  4.027474     4
# 1                    Inflight service  3.969461     4
# 2                        Seat comfort  3.966530     4
# 3                    Baggage handling  3.966396     4
# 4              Inflight entertainment  3.964931     4
# 5                    On-board service  3.857324     4
# 6                    Leg room service  3.822143     4
# 7                         Cleanliness  3.744342     4
# 8                     Checkin service  3.646041     4
# 9                      Food and drink  3.521310     4
# 10              Inflight wifi service  3.161288     4
# 11             Ease of Online booking  3.031582     4
# 12                      Gate location  2.977879     3
# 13  Departure/Arrival time convenient  2.970305     4

# %%
plt.figure(figsize = (20,5))

plt.subplot(1,2,1)
sns.barplot(data = df_ratings_satisfied_summary, x ='Features', y = 'Mean', palette = 'rocket')
plt.xticks(rotation = 60)
plt.title('Mean of Ratings Features of Satisfied Cust.')

plt.subplot(1,2,2)
sns.barplot(data = df_ratings_satisfied_summary, x ='Features', y = 'Mode', palette = 'Blues_r')
plt.xticks(rotation = 60)
plt.title('Mode of Ratings Features of Satisfied Cust.')

plt.show()

# %% [markdown]
# Berdasarkan nilai rata-rata dan modus dari rating masing-masing fitur khusus untuk penumpang yang PUAS adalah sebagai berikut:
# - 3 fitur teratas yang memiliki nilai rata-rata dan modus tertinggi adalah:
#     - Online boarding
#     - Inflight service
#     - Seat comfort
# - 3 fitur terbawah yang memiliki nilai rata-rata dan modus terendah adalah:
#     - Ease for online booking
#     - Gate location
#     - Departure/Arrival time convenient

# %% [markdown]
# ##### Insight
# - Berdasarkan overall rating, rating berdasarkan penumpang netral/dissatisfied, rating berdasarkan penumpang satisfied, terdapat ketidak-konsistenan rating antara lain:
#     - Bagi penumpang yang netral/tidak puas, Departure/Arrival time convenient memiliki penilaian yang cukup tinggi dan masuk 3 teratas, namun bagi penumpang yang puas, Departure/Arrival time convenient menjadi yang terendah
#     - Bagi penumpang yang puas, online boarding menjadi aspek yang terbaik, namun bagi penumpang yang netral/tidak puas online boarding menjadi penilaian yang cukup rendah dan masuk 3 terendah, bisa jadi hal ini dipengaruhi oleh hal lain seperti usia, yang mana bagi beberapa kategori usia kecakapan digital menjadi satu hal yang terpengaruh
#     - Inflight service menjadi aspek yang sangat baik, dibuktikan bahwa secara overall Inflight service menjadi aspek teratas, kemudian bagi penumpang yang netral/tidak puas dan puas juga menjadi aspek 3 teratas
#     - Untuk aspek Ease for Online booking menjadi aspek yang dinilai kurang baik, dibuktikan pada overall rating, segment penumpang netral/tidak puas, dan segment penumpang puas mberada pada peringkat 3 terendah
#     - Selain itu untuk Inflight wifi service secara overall dan segment penumpang netral/tidak puas menjadi aspek terendah, namun bagi segment yang puas berada pada peringkat 4 terendah

# %% [markdown]
# #### c. Segment Gender

# %% [markdown]
# Berdasarkan segmentasi gender penumpang dibagi menjadi 2 kategori yaitu: Male (Laki-laki) dan Female (Perempuan)
#
# Berikut penjelasannya:

# %%
proporsi_gender = proporsi_kepuasan(airline,'Gender','satisfaction')
proporsi_gender
# Out:
# satisfaction  Count Neutral or Dissatisfied  Count Satisfied  Total  \
# Gender
# Female                                30193            22534  52727
# Male                                  28686            22491  51177
#
# satisfaction  % Neutral or Dissatisfied  % Satisfied  % Total
# Gender
# Female                            57.26        42.74    100.0
# Male                              56.05        43.95    100.0

# %%
plt.figure(figsize=(20, 5))
plt.style.use('bmh')

#countplot Satisfaction by Gender
plt.subplot(131)
countplot(airline, 'satisfaction', 'Gender')
plt.title('Satisfaction by Gender')

#pieplot Male Passenger Satisfaction
plt.subplot(132)
pieplot_by_Segment(airline, 'Gender', 'Male', 'satisfaction', 'Neutral or Dissatisfied', 'Satisfied')
plt.title('Male Pass. Satisfaction')

#pieplot Female Passenger Satisfaction
plt.subplot(133)
pieplot_by_Segment(airline, 'Gender', 'Female', 'satisfaction', 'Neutral or Dissatisfied', 'Satisfied')
plt.title('Female Pass. Satisfaction')


plt.show()

# %% [markdown]
# Berdasarkan segmentasi gender, dari 103.904 penumpang adalah sebagai berikut:
# - Terdapat 51.177 penumpang laki-laki (Male).
#     - Sejumlah 28.686 penumpang atau 56.05% netral atau tidak puas.
#     - Sejumlah 22.491 penumpang atau 43.95% puas.
# - Terdapat 52.727 penumpang perempuan (Female).
#     - Sejumah 30.193 penumpang atau 57.26% netral atau tidak puas.
#     - Sedangkan 22.534 penumpang atau 42.74% puas.
#
# Secara sekilas antara kepuasan pelanggan laki-laki dan perempuan tidak ada beda signifikan. Untuk membuktikan hal tersebut dilakukan uji statistik sebagai berikut:

# %%
# Menguji hipotesis apabila gender mempengaruhi kepuasan penumpang dengan chi squared contingency
# H0 = Gender tidak mempengaruhi kepuasan pelanggan

df_ct = pd.crosstab(airline['Gender'],airline['satisfaction'])
score, pval, dof,exp = chi2_contingency(df_ct)
if pval >= 0.05:
    print('H0 diterima')
else:
    print('H0 ditolak')
# Out:
# H0 ditolak

# %% [markdown]
# Berdasarkan hasil uji statistik diatas H0 ditolak, atau dapat dikatakan tidak cukup bukti bahwa gender tidak memperngaruhi kepuasan pelanggan.

# %%
ratings_detail_per_category(airline, 'Gender')

# %% [markdown]
# Summary
#
# Jika dilihat detail per masing-masing rating yang diberikan oleh masing-masing segment Gender juga tidak ditemukan adanya perbedaan yang signifikan antara laki-laki dan perempuan

# %% [markdown]
# #### d. Segment Customer Type

# %% [markdown]
# Berdasarkan segmentasi customer type, penumpang dibagi menjadi 2 kategori yaitu: Loyal customer dan Disloyal customer
#
# Berikut penjelasannya:

# %%
proporsi_customer_type = proporsi_kepuasan(airline,'Customer Type','satisfaction')
proporsi_customer_type
# Out:
# satisfaction       Count Neutral or Dissatisfied  Count Satisfied  Total  \
# Customer Type
# Loyal Customer                             44390            40533  84923
# disloyal Customer                          14489             4492  18981
#
# satisfaction       % Neutral or Dissatisfied  % Satisfied  % Total
# Customer Type
# Loyal Customer                         52.27        47.73    100.0
# disloyal Customer                      76.33        23.67    100.0

# %%
plt.figure(figsize=(20,5))
plt.style.use('bmh')

#countplot Satisfaction by Customer Type
plt.subplot(131)
countplot(airline, 'satisfaction', 'Customer Type')
plt.title('Satisfaction by Customer Type')

#pieplot Loyal Customer Passenger Satisfaction
plt.subplot(132)
pieplot_by_Segment(airline, 'Customer Type', 'Loyal Customer', 'satisfaction', 'Neutral or Dissatisfied', 'Satisfied')
plt.title('Loyal Customer Pass. Satisfaction')

#pieplot Disloyal Customer Passenger Satisfaction
plt.subplot(133)
pieplot_by_Segment(airline, 'Customer Type', 'disloyal Customer', 'satisfaction', 'Neutral or Dissatisfied', 'Satisfied')
plt.title('Disloyal Customer Pass. Satisfaction')


plt.show()

# %% [markdown]
# Berdasarkan segmentasi cutomer type, dari 103.904 penumpang adalah sebagai berikut:
# - Terdapat 84.923 penumpang Loyal customer.
#     - Sejumlah 44.390 penumpang atau 52.27% netral atau tidak puas.
#     - Sejumlah 40.533 penumpang atau 47.73% puas.
# - Terdapat 18.981 penumpang Disloyal customer.
#     - Sejumah 14.489 penumpang atau 76.33% netral atau tidak puas.
#     - Sejumlah 4.492 penumpang atau 23.67% puas.
#
# Dari segment Loyal customer sekilas tidak ada beda signifikan antara customer yang netral atau tidak puas dengan customer yang puas. Berbeda dengan segment Disloyal customer, pada segment ini didominasi customer merasa netral atau tidak puas dengan pelayanan maskapai.

# %%
df_ct = pd.crosstab(airline['Customer Type'],airline['satisfaction'])
score, pval, dof,exp = chi2_contingency(df_ct)
if pval >= 0.05:
    print('H0 diterima')
else:
    print('H0 ditolak')
# Out:
# H0 ditolak

# %% [markdown]
# Berdasarkan hasil uji statistik diatas H0 ditolak, atau dapat dikatakan tidak cukup bukti bahwa customer type tidak memperngaruhi kepuasan pelanggan.

# %%
ratings_detail_per_category(airline, 'Customer Type')
plt.title ('Ratings by Customer Type')
# Out:
# Text(0.5, 1.0, 'Ratings by Customer Type')

# %% [markdown]
# Jika dilihat lebih detail berdasarkan grafik rating diatas dapat dilihat pola sebagai berikut:
# - Untuk aspek inflight wifi service baik loyal customer maupun disoyal customer memberikan score rata-rata yaitu teringgi pada score 2 dan 3
# - Untuk aspek Departure/arrival time convenient loyal customer cenderung memberikan rating tinggi yaitu 4 dan 5 sedangkan disloyal customer memberikan nilai yang cenderung merata
# - Untuk aspek ease of online booking baik loyal customer maupun disoyal customer memberikan score rata-rata yaitu teringgi pada score 2 dan 3
# - Untuk aspek gate location baik loyal customer maupun disoyal customer memberikan score rata-rata yaitu teringgi pada score 2 dan 3
# - Untuk aspek food and drink loyal customer cenderung memberikan rating merata pada score 2-5 sedangkan disloyal customer memberikan nilai yang cenderung merata
# - Untuk aspek online boarding loyal customer cenderung memberikan rating tinggi yaitu 4 sedangkan disloyal customer memberikan score rata-rata pada score 2 dan 3
# - Untuk aspek seat comfort loyal customer cenderung memberikan rating tinggi yaitu 4 sedangkan disloyal customer memberikan score merata
# - Untuk aspek inflight entertainment loyal customer cenderung memberikan rating tinggi yaitu 4 sedangkan disloyal customer memberikan score merata
# - Untuk aspek on-board service loyal customer cenderung memberikan rating tinggi yaitu 4 sedangkan disloyal customer memberikan score rata-rata pada score 3 dan 4
# - Untuk aspek legroom loyal customer cenderung memberikan rating tinggi yaitu 4 sedangkan disloyal customer memberikan score merata
# - Untuk aspek baggage handling loyal customer dan disloyal customer cenderung memberikan rating tinggi yaitu 4
# - Untuk aspek checkin service loyal customer dan disloyal customer cenderung memberikan rating rata-rata yaitu 3 dan 4
# - Untuk aspek inflight service loyal customer dan disloyal customer cenderung memberikan rating tinggi yaitu 4
# - Untuk aspek cleanliness loyal customer cenderung memberikan rating tinggi yaitu 4 sedangkan disloyal customer memberikan score merata

# %% [markdown]
# Summary
#
# - Secara keseluruhan pada dasarnya loyal customer cenderung lebih puas dengan aspek-aspek pelayanan penerbangan daripada disloyal customer yang cenderung memberikan nilai rata-rata.
# - Namun menurut loyal customer ada berapa aspek yang perlu ditingkatkan seperti inflight wifi service, ease of boongking online dan gate location, dibuktikan dari penilaian loyal customer yang cenderung rata-rata pada score 3

# %% [markdown]
# #### e. Segment Customer Age

# %% [markdown]
# Berdasarkan segmentasi usia penumpang untuk mempermudah analisa maka usia dikelompokkan menjadi 5 kategori umur yaitu:
# 1) Children rentang usia 0-14 tahun
# 2) Early Working Age rentang usia 15-24 tahun
# 3) Prime Working Age rentang usia 25-54 tahun
# 4) Mature Working Age rentang usia 55-64 tahun
# 5) Elderly rentang usia 65 tahun keatas

# %%
airline_modified = airline.copy()

# %%
def kategori_usia(usia):    
    if usia < 15: 
        return 'Children'
    elif (usia >= 15) and (usia < 25): 
        return 'Early Working Age'
    elif (usia >= 25) and (usia < 55):
        return 'Prime Working Age'
    elif (usia >= 55) and (usia < 65):
        return 'Mature Working Age'
    elif usia >= 65:
        return 'Elderly'

airline_modified['Age Category'] = airline_modified['Age'].apply(lambda Usia : kategori_usia(Usia))

# %%
airline_modified.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                  4                       3              1
# ...

# %%
proporsi_age_category = proporsi_kepuasan(airline_modified,'Age Category','satisfaction')
proporsi_age_category
# Out:
# satisfaction        Count Neutral or Dissatisfied  Count Satisfied  Total  \
# Age Category
# Children                                     4505              725   5230
# Early Working Age                            9890             4695  14585
# Elderly                                      3873              875   4748
# Mature Working Age                           7163             6901  14064
# Prime Working Age                           33448            31829  65277
#
# satisfaction        % Neutral or Dissatisfied  % Satisfied  % Total
# Age Category
# Children                                86.14        13.86    100.0
# Early Working Age                       67.81        32.19    100.0
# Elderly                                 81.57        18.43    100.0
# Mature Working Age                      50.93        49.07    100.0
# Prime Working Age                       51.24        48.76    100.0

# %%
plt.figure(figsize=(10,5))
plt.style.use('bmh')

#countplot Satisfaction by Age Category
countplot(airline_modified, 'satisfaction', 'Age Category')
plt.title('Satisfaction by Age Category')

plt.show()

# %%
plt.figure(figsize=(27,10))
plt.style.use('bmh')

#pieplot Children Passenger Satisfaction
plt.subplot(151)
pieplot_by_Segment(airline_modified, 'Age Category', 'Children', 'satisfaction', 'Neutral or Dissatisfied', 'Satisfied')
plt.title('Children Pass. Satisfaction')

#pieplot Early Working Age Passenger Satisfaction
plt.subplot(152)
pieplot_by_Segment(airline_modified, 'Age Category', 'Early Working Age', 'satisfaction', 'Neutral or Dissatisfied', 'Satisfied')
plt.title('Early Working Age Pass. Satisfaction')

#pieplot Prime Working Age Passenger Satisfaction
plt.subplot(153)
pieplot_by_Segment(airline_modified, 'Age Category', 'Prime Working Age', 'satisfaction', 'Neutral or Dissatisfied', 'Satisfied')
plt.title('Prime Working Age Pass. Satisfaction')

#pieplot Mature Working Age Passenger Satisfaction
plt.subplot(154)
pieplot_by_Segment(airline_modified, 'Age Category', 'Mature Working Age', 'satisfaction', 'Neutral or Dissatisfied', 'Satisfied')
plt.title('Mature Working Age Pass. Satisfaction')

#pieplot Elderly Passenger Satisfaction
plt.subplot(155)
pieplot_by_Segment(airline_modified, 'Age Category', 'Elderly', 'satisfaction', 'Neutral or Dissatisfied', 'Satisfied')
plt.title('Elderly Pass. Satisfaction')


plt.show()

# %% [markdown]
# Berdasarkan segmentasi usia dari 103.904 penumpang distribusi pengelompokannya adalah sebagai berikut:
# - Children pass. sebanyak 5.250 penumpang.
#     - Sebanyak 4.505 penumpang atau 86,14% netral atau tidak puas.
#     - Sebanyak 725 penumpang atau 13.86% puas.
# - Early Working Age pass. adalah sebanyak 14.585 penumpang.
#     - Sebanyak 9.890 penumpang atau 67,81% netral atau tidak puas.
#     - Sebanyak 4.695 penumpang atau 32.19% puas.
# - Prime Working Age pass. adalah sebanyak 65.277 penumpang.
#     - Sebanyak 33.448 penumpang atau 51,24% netral atau tidak puas.
#     - Sebanyak 31.829 penumpang atau 48.76% puas.
# - Mature Wrorking Age pass. adalah sebanyak 14.064 penumpang.
#     - Sebanyak 7.163 penumpang atau 50,93% netral atau tidak puas.
#     - Sebanyak 6.901 penumpang atau 49.07% puas.
# - Elderly pass. adalah sebanyak 4.748 penumpang.
#     - Sebanyak 3.873 penumpang atau 81,57% netral atau tidak puas.
#     - Sebanyak 875 penumpang atau 18.43% puas
#
# Secara keseluruhan penumpang didominasi oleh Prime Working Age dan proporsi kepuasannya adalah hampir sama.

# %%
plt.figure(figsize=(10,5))

sns.histplot(data = airline, x = airline[airline['satisfaction']=='neutral or dissatisfied']['Age'], kde = True, color = 'red')
sns.histplot(data = airline, x = airline[airline['satisfaction']=='satisfied']['Age'], kde = True, color = 'blue')
plt.legend(labels=['satisfied','netral or dissatisfied'])
plt.title('Satisfaction based on Age', fontsize=16)

plt.show()

# %% [markdown]
# Dari grafik diatas, dapat dilihat sekilas bahwa distribusi tidak normal. Penumpang yang menjawab puas terhadap pelayanan maskapai berkisar diumur 40 sampai 55. Sedangkan penumpang yang menjawab tidak puas memiliki fluktuasi, berkisar dari umur 22 sampai 40.

# %%
airline_modified.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                  4                       3              1
# ...

# %%
df_ct = pd.crosstab(airline_modified['Age Category'],airline_modified['satisfaction'])
score, pval, dof,exp = chi2_contingency(df_ct)
if pval >= 0.05:
    print('H0 diterima')
else:
    print('H0 ditolak')
# Out:
# H0 ditolak

# %% [markdown]
# Berdasarkan hasil uji statistik diatas H0 ditolak, atau dapat dikatakan tidak cukup bukti bahwa kaetgori usia tidak memperngaruhi kepuasan pelanggan.

# %%
ratings_detail_per_category(airline_modified, 'Age Category')
plt.title ('Ratings by Age Category')
# Out:
# Text(0.5, 1.0, 'Ratings by Age Category')

# %% [markdown]
# Untuk memfokuskan analisa dari segment usia, difokuskan analisa kali ini kepada segment Prime Working Age pass:
# Berdasarkan grafik diatas dapat dilihat pola sebagai berikut:
# - Untuk aspek inflight wifi service customer Prime Working Age memberikan score rata-rata yaitu teringgi pada score 2 dan 3
# - Untuk aspek Departure/arrival time convenient customer Prime Working Age cenderung memberikan rating tinggi yaitu 4 dan 5
# - Untuk aspek ease of online booking baik customer Prime Working Age memberikan score rata-rata yaitu teringgi pada score 2 dan 3
# - Untuk aspek gate location baik customer Prime Working Age memberikan score rata-rata yaitu teringgi pada score 3 dan 4
# - Untuk aspek food and drink customer Prime Working Age cenderung memberikan rating merata pada score 2-5
# - Untuk aspek online boarding customer Prime Working Age cenderung memberikan rating tinggi yaitu 4
# - Untuk aspek seat comfort customer Prime Working Age cenderung memberikan rating tinggi yaitu 4
# - Untuk aspek inflight entertainment customer Prime Working Age cenderung memberikan rating tinggi yaitu 4
# - Untuk aspek on-board service customer Prime Working Age cenderung memberikan rating tinggi yaitu 4
# - Untuk aspek legroom customer Prime Working Age cenderung memberikan rating tinggi yaitu 4
# - Untuk aspek baggage handling customer Prime Working Age cenderung memberikan rating tinggi yaitu 4
# - Untuk aspek checkin service customer Prime Working Age cenderung memberikan rating rata-rata yaitu 3 dan 4
# - Untuk aspek inflight service customer Prime Working Age cenderung memberikan rating tinggi yaitu 4
# - Untuk aspek cleanliness customer Prime Working Age cenderung memberikan rating tinggi yaitu 4

# %% [markdown]
# Summary
#
# - Secara keseluruhan customer dengan segmentasi Prime Working Age memberikan rating cenderung tinggi kecuali pada aspek inflight wifi service, ease of online booking dan gate location yang mana nilai yang diberikan cenderung rata-rata

# %% [markdown]
# #### f. Segment Type of Travel

# %% [markdown]
# Berdasarkan segmentasi type of travel, penumpang dibagi menjadi 2 kategori yaitu: Business travel dan Personal travel
#
# Berikut penjelasannya:

# %%
proporsi_type_of_travel = proporsi_kepuasan(airline,'Type of Travel','satisfaction')
proporsi_type_of_travel
# Out:
# satisfaction     Count Neutral or Dissatisfied  Count Satisfied  Total  \
# Type of Travel
# Business travel                          29909            41746  71655
# Personal Travel                          28970             3279  32249
#
# satisfaction     % Neutral or Dissatisfied  % Satisfied  % Total
# Type of Travel
# Business travel                      41.74        58.26    100.0
# Personal Travel                      89.83        10.17    100.0

# %%
plt.figure(figsize=(20,4))
plt.style.use('bmh')

#countplot Satisfaction by Type of Travel
plt.subplot(1,3,1)
countplot(airline, 'satisfaction', 'Type of Travel')
plt.title('Satisfaction by Type of Travel')

#pieplot Type of Travel Passenger Satisfaction
plt.subplot(1,3,2)
pieplot_by_Segment(airline, 'Type of Travel', 'Business travel', 'satisfaction', 'Neutral or Dissatisfied', 'Satisfied')
plt.title('Business Travel Pass. Satisfaction')

#pieplot Type of Travel Passenger Satisfaction
plt.subplot(1,3,3)
pieplot_by_Segment(airline, 'Type of Travel', 'Personal Travel', 'satisfaction', 'Neutral or Dissatisfied', 'Satisfied')
plt.title('Personal Travel Customer Pass. Satisfaction')

plt.show()

# %% [markdown]
# Berdasarkan segmentasi type of travel, dari 103.904 penumpang adalah sebagai berikut:
# - Terdapat 71.655 penumpang bussiness travel.
#     - Sejumlah 29.909 penumpang atau 41.74% netral atau tidak puas.
#     - Sejumlah 41.746 penumpang atau 58.26% puas.
# - Terdapat 32.247 penumpang personal travel.
#     - Sejumlah 28.470 penumpang atau 89.83% netral atau tidak puas.
#     - Sejumlah 3.279 penumpang atau 10.17% puas.
#
# Dari segment type of travel, terdapat perbedaan yang cukup mencolok pada penumpang yang puas, yang mana penumpang puas didominasi oleh penumpang bussiness travel, sedangkan untuk penumpang yang netral/tidak puas memliki jumlah yang tidak signifikan antara business travel dengan personal travel

# %%
df_ct = pd.crosstab(airline['Type of Travel'],airline['satisfaction'])
score, pval, dof,exp = chi2_contingency(df_ct)
if pval >= 0.05:
    print('H0 diterima')
else:
    print('H0 ditolak')
# Out:
# H0 ditolak

# %% [markdown]
# Berdasarkan hasil uji statistik diatas H0 ditolak, atau dapat dikatakan tidak cukup bukti bahwa type of travel tidak mempengaruhi kepuasan pelanggan.

# %%
ratings_detail_per_category(airline, 'Type of Travel')
plt.title ('Ratings by Type of Travel')
# Out:
# Text(0.5, 1.0, 'Ratings by Type of Travel')

# %% [markdown]
# Berdasarkan grafik diatas dapat dilihat pola sebagai berikut:
# - Untuk aspek inflight wifi service customer dengan Bussiness travel maupun Personal Travel memberikan score rata-rata yaitu teringgi pada score 2 dan 3
# - Untuk aspek Departure/arrival time convenient customer dengan Personal Travel cenderung memberikan rating tinggi yaitu 4 dan 5, sedangkan customer Bussiness travel cenderung memberikan niali rata-rata pada score 2, 3, dan 4
# - Untuk aspek ease of online booking baik customer dengan Bussiness travel maupun Personal Travel memberikan score rata-rata yaitu teringgi pada score 2 dan 3
# - Untuk aspek gate location baik customer dengan Bussiness travel maupun Personal Travel memberikan score rata-rata yaitu teringgi pada score 3 dan 4
# - Untuk aspek food and drink customer dengan Bussiness travel maupun Personal Travel cenderung memberikan rating merata pada score 2-5
# - Untuk aspek online boarding customer dengan Bussiness travel cenderung memberikan rating tinggi yaitu 4, sedangkan customer Personal travel cenderung memberikan nilai rata-rata pada score 3
# - Untuk aspek seat comfort customer dengan Bussiness travel maupun Personal Travel cenderung memberikan rating tinggi yaitu 4
# - Untuk aspek inflight entertainment customer dengan Bussiness travel cenderung memberikan rating tinggi yaitu 4, sedangkan untuk Personal travel memberikan nilai yang tersebar merata
# - Untuk aspek on-board service customer dengan Bussiness travel cenderung memberikan rating tinggi yaitu 4, sedangkan untuk customer Personal travel cenderung memberikan nilai 3 dan 4
# - Untuk aspek legroom service customer dengan Bussiness travel cenderung memberikan rating tinggi yaitu 4, sedangkan customer Personal tavel memberikan nilai rata-rata pada score 3 dan 2
# - Untuk aspek baggage handling customer dengan Bussiness travel maupun Personal Travel cenderung memberikan rating tinggi yaitu 4
# - Untuk aspek checkin service customer dengan Bussiness travel maupun Personal Travel cenderung memberikan rating cukup tinggi yaitu 3 dan 4
# - Untuk aspek inflight service customer dengan Bussiness travel maupun Personal Travel cenderung memberikan rating tinggi yaitu 4
# - Untuk aspek cleanliness customer dengan Bussiness travel maupun Personal Travel cenderung memberikan rating tinggi yaitu 4, sedangkan Personal travel pada nilai 3 dan 4

# %% [markdown]
# Summary
# - Secara keseluruhan, untuk customer dengan tujuan Bussiness Travel memberikan nilai tinggi kecuali pada aspek Inflight Wifi Service, Ease of Online Booking, dan Gate Location.
# - Sedangkan untuk customer dengan tujuan Personal Travel cenderung memberikan nilai rata-rata pada beberapa aspek, antara lain, Inflight Wifi Service, Departure/Arrival Time Convenient, Ease of Online Booking, Gate Location, Online Boarding, Inflight Entertainment, dan Leg room service.
# - Perbedaan ini dapat disebabkan karena customer untuk Personal Travel yang tidak terkait dengan kepentingan bisnis lebih mengutamakan kenyamanan dan entertain yang kemudian seakan akan lebih kritis terhadap aspek Inflight Entertainment dan Leg Room service daripada customer dengan tujuan Bussiness Travel

# %% [markdown]
# #### g. Segment Class

# %% [markdown]
# Berdasarkan segmentasi Class, penumpang dibagi menjadi 3 kategori yaitu: Business, Economic (Eco) dan Economic Plus (Eco Plus)
#
# Berikut penjelasannya:

# %%
proporsi_class = proporsi_kepuasan(airline,'Class','satisfaction')
proporsi_class
# Out:
# satisfaction  Count Neutral or Dissatisfied  Count Satisfied  Total  \
# Class
# Business                              15185            34480  49665
# Eco                                   38044             8701  46745
# Eco Plus                               5650             1844   7494
#
# satisfaction  % Neutral or Dissatisfied  % Satisfied  % Total
# Class
# Business                          30.57        69.43    100.0
# Eco                               81.39        18.61    100.0
# Eco Plus                          75.39        24.61    100.0

# %%
plt.figure(figsize=(20,4))
plt.style.use('bmh')

#countplot Satisfaction by Class
plt.subplot(1,4,1)
countplot(airline, 'satisfaction', 'Class')
plt.title('Satisfaction by Class')

#pieplot Class Passenger Satisfaction
plt.subplot(1,4,2)
pieplot_by_Segment(airline, 'Class', 'Business', 'satisfaction', 'Satified', 'Neutral or Dissatisfied')
plt.title('Business Pass. Satisfaction')

#pieplot Class Passenger Satisfaction
plt.subplot(1,4,3)
pieplot_by_Segment(airline, 'Class', 'Eco', 'satisfaction', 'Neutral or Dissatisfied', 'Satisfied')
plt.title('Eco Pass. Satisfaction')

#pieplot Class Passenger Satisfaction
plt.subplot(1,4,4)
pieplot_by_Segment(airline, 'Class', 'Eco Plus', 'satisfaction', 'Neutral or Dissatisfied', 'Satisfied')
plt.title('Eco Plus Pass. Satisfaction')

plt.show()

# %% [markdown]
# Berdasarkan segmentasi Class, dari 103.904 penumpang adalah sebagai berikut:
# - Terdapat 49.665 penumpang Business Class.
#     - Sejumlah 15.185 penumpang atau 30,57% netral atau tidak puas.
#     - Sejumlah 34.480 penumpang atau 69,43% puas.
# - Terdapat 46.745 penumpang Economic Class.
#     - Sejumlah 38.044 penumpang atau 81,39% netral atau tidak puas.
#     - Sejumlah 4.492 penumpang atau 23,67% puas.
# - Terdapat 7.494 penumpang Economic Plus.
#     - Sejumlah 5.650 penumpang atau 75,39% netral atau tidak puas.
#     - Sejulah 1.844 penumpang atau 24,61% puas.
#
# Secara keseluruhan penumpang terbagi menjadi 2 Class terbanyak yaitu Bussiness Class dan Economic Class, hanya sebagian yang mengambil Economic Plus Class. Dari 2 class terbanyak tersebut, penumpang Bussiness Class cenderung puas, sedangkan penumpang pada Economic Class dan Economic Plus Class cenerung netral atau tidak puas.

# %%
df_ct = pd.crosstab(airline['Type of Travel'],airline['satisfaction'])
score, pval, dof,exp = chi2_contingency(df_ct)
if pval >= 0.05:
    print('H0 diterima')
else:
    print('H0 ditolak')
# Out:
# H0 ditolak

# %% [markdown]
# Berdasarkan hasil uji statistik diatas H0 ditolak, atau dapat dikatakan tidak cukup bukti bahwa Class tidak memperngaruhi kepuasan pelanggan.

# %%
ratings_detail_per_category(airline, 'Class')
plt.title ('Ratings by Class')
# Out:
# Text(0.5, 1.0, 'Ratings by Class')

# %% [markdown]
# Untuk memfokuskan analisa dari segment usia, difokuskan analisa kali ini kepada segment Business Class dan Economic Class passengers:
#
# Berdasarkan grafik diatas dapat dilihat pola sebagai berikut:
# - Untuk aspek inflight wifi service customer dengan Business Class maupun Economic Class memberikan score rata-rata yaitu teringgi pada score 2 dan 3
# - Untuk aspek Departure/arrival time convenient customer dengan Economic Class cenderung memberikan rating tinggi yaitu 4 dan 5, sedangkan customer Business Class cenderung memberikan niali rata-rata pada score 2, 3, dan 4
# - Untuk aspek ease of online booking baik customer dengan Economic Class memberikan score rata-rata yaitu teringgi pada score 2 dan 3, sedangkan customer Business Class cenderung memberikan nilai merata
# - Untuk aspek gate location baik customer dengan Business Class maupun Economic Class memberikan score rata-rata yaitu teringgi pada score 3 dan 4
# - Untuk aspek food and drink customer dengan Business Class maupun Economic Class cenderung memberikan rating merata pada score 2-5
# - Untuk aspek online boarding customer dengan Business Class cenderung memberikan rating tinggi yaitu 4, sedangkan customer Economic Class cenderung memberikan nilai rata-rata pada score 3
# - Untuk aspek seat comfort customer dengan Business Class maupun Economic Class cenderung memberikan rating tinggi yaitu 4
# - Untuk aspek inflight entertainment customer dengan Business Class dan Economic Class cenderung memberikan rating tinggi yaitu 4 meskipun pada Economic Class tidak setinggi Business Class
# - Untuk aspek on-board service customer dengan Business Class cenderung memberikan rating tinggi yaitu 4, sedangkan untuk customer Economic Class cenderung memberikan nilai 3 dan 4
# - Untuk aspek legroom service customer dengan Business Class cenderung memberikan rating tinggi yaitu 4, sedangkan customer Economic Class memberikan nilai rata-rata pada score 2, 3, dan 4
# - Untuk aspek baggage handling customer dengan Business Class maupun Economic Class cenderung memberikan rating tinggi yaitu 4
# - Untuk aspek checkin service customer dengan Business Class maupun Economic Class cenderung memberikan rating cukup tinggi yaitu 3 dan 4
# - Untuk aspek inflight service customer dengan Business Class maupun Economic Class cenderung memberikan rating tinggi yaitu 4
# - Untuk aspek cleanliness customer dengan Business Class maupun Economic Class cenderung memberikan rating tinggi yaitu 4

# %% [markdown]
# Summary
# - Secara keseluruhan, untuk customer Business Class memberikan nilai tinggi kecuali pada aspek Inflight Wifi Service, Departure/Arrival Time Convenient, Ease of Online Booking, dan Gate Location.
# - Sedangkan untuk customer Economic Class cenderung memberikan nilai rata-rata pada seluruh aspek, hanya beberapa aspek yagn dinilai tinggi yaitu, Deperture/Arrival Time Cenvenient dan Inflight Service
# - Perbedaan ini dapat disebabkan karena customer Business Class memiliki fasilitas penerbangan yang lebih baik daripada Economic Class, sehingga penumpang pada Economic Class cenderung memberikan nilai rata-rata pada kebanyakan aspek penerbangan.
# - Hal yang perlu diperhatikan adalah Inflight Wifi Service, Ease of Online Booking dan Gate Location yang mana kedua segment menilai kurang baik.
# - Sedangkan untuk Departure/Arrival Time Convenient kedua segment memberikan penilaian yang berbeda bisa jadi karena ekspektasi penumpang Business Class yang lebih tinggi sehingga berharap penerbangan dapat lebih tepat waktu, dibandingkan dengan ekspektasi penumpang Economic Class

# %% [markdown]
# #### h. Flight Distance

# %%
airline_modified_complete = airline_modified.copy()

# %% [markdown]
# Berdasarkan pembagaian kategori jarak penerbangan, akan dibagi menjadi 2 kategori yaitu:
# - Short flight jika jarak penerbangan kurang dari 3000 miles
# - Long flight jika jatan penerbangan lebih dari 3000 miles

# %%
def kategori_jarak_terbang(Jarak):    
    if Jarak < 3000: 
        return 'Short Flight'
    elif Jarak >= 3000:
        return 'Long Flight'

airline_modified_complete['Flight Distance Category'] = airline_modified_complete['Flight Distance'].apply(lambda Jarak : kategori_jarak_terbang(Jarak))

# %%
airline_modified_complete.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                  4                       3              1
# ...

# %%
plt.figure(figsize=(10,5))

sns.histplot(data = airline, x = airline[airline['satisfaction']=='neutral or dissatisfied']['Flight Distance'], kde = True, color = 'red')
sns.histplot(data = airline, x = airline[airline['satisfaction']=='satisfied']['Flight Distance'], kde = True, color = 'blue')
plt.legend(labels=['netral or dissatisfied','satisfied'])
plt.title('Satisfaction based on Flight Distance', fontsize=16)

plt.show()

# %% [markdown]
# Dapat dilihat pada grafik diatas, bahwa penumpang dengan jarak terbang dibawah 1000 miles cenderung berimbang antara penumpang puas dan netral atau tidak puas. Namun perbedaan yang cukup signifikan terjadi ketika jarak penerbangan diatas 1000 miles, yang mana lebih banyak penumpang yang puas daripada penumpang yang netrak atau tidak puas.
#
# Sekilas artinya bahwa penumpang dengan jarak terbang yang jauh mungkin mendapatkan fasilitas yang memadai dan mencapai ekspektasi daripada service pada saat penerbangan jarak pendek.

# %%
proporsi_flight_distance_category = proporsi_kepuasan(airline_modified_complete,'Flight Distance Category','satisfaction')
proporsi_flight_distance_category
# Out:
# satisfaction              Count Neutral or Dissatisfied  Count Satisfied  \
# Flight Distance Category
# Long Flight                                        1868             6405
# Short Flight                                      57011            38620
#
# satisfaction              Total  % Neutral or Dissatisfied  % Satisfied  \
# Flight Distance Category
# Long Flight                8273                      22.58        77.42
# Short Flight              95631                      59.62        40.38
#
# satisfaction              % Total
# Flight Distance Category
# Long Flight                 100.0
# Short Flight                100.0

# %%
plt.figure(figsize=(20,5))
plt.style.use('bmh')

#countplot Satisfaction by Flight Distance Category
plt.subplot(1,3,1)
countplot(airline_modified_complete, 'satisfaction', 'Flight Distance Category')
plt.title('Satisfaction by Flight Distance Category')

plt.subplot(1,3,2)
pieplot_by_Segment(airline_modified_complete, 'Flight Distance Category', 'Short Flight','satisfaction', 'Neutral or Dissatisfied', 'Satisfied')
plt.title('Short Flight Pass. Satisfaction')

plt.subplot(1,3,3)
pieplot_by_Segment(airline_modified_complete, 'Flight Distance Category', 'Long Flight','satisfaction', 'Satisfied', 'Neutral or Dissatisfied')
plt.title('Long Flight Pass. Satisfaction')

plt.show()

# %% [markdown]
# Berdasarkan segmentasi Jarak Terbang, dari 103.904 penumpang adalah sebagai berikut:
# - Terdapat 8.273 penumpang Long Flight.
#     - Sejumlah 1.865 penumpang atau 22,58% netral atau tidak puas.
#     - Sejumlah 6.405 penumpang atau 77,42% puas.
# - Terdapat 95.631 penumpang Short Flight.
#     - Sejumlah 57.011 penumpang atau 59,62% netral atau tidak puas.
#     - Sejumlah 38.620 penumpang atau 40,638% puas.
#
# Secara keseluruhan dominan perjalanan yang dilakukan adalah Short Flight yang didominasi penumpang menilai netral atau tidak puas. Sedangkan untuk perjalanan jauh atau Long Flight lebih banyak penumpang yang puas daripada netral atau tidak puas, meskipun jumlah penumpang yang melakukan perjalanan Long Flight jauh lebih sedikit.

# %%
ratings_detail_per_category(airline_modified_complete, 'Flight Distance Category')
plt.title ('Ratings by Flight Distance Category')
# Out:
# Text(0.5, 1.0, 'Ratings by Flight Distance Category')

# %% [markdown]
# Berdasarkan grafik diatas dapat dilihat pola sebagai berikut:
# - Untuk aspek inflight wifi service customer dengan Short Flight maupun Long Flight memberikan score rata-rata yaitu teringgi pada score 2 dan 3
# - Untuk aspek Departure/arrival time convenient customer dengan Short Flight cenderung memberikan rating tinggi yaitu 4 dan 5, sedangkan customer long Flight cenderung memberikan niali rata-rata pada score 2, 3, dan 4
# - Untuk aspek ease of online booking baik customer dengan Short Flight memberikan score rata-rata yaitu teringgi pada score 2 dan 3, sedangkan customer Long Flight cenderung memberikan nilai merata
# - Untuk aspek gate location baik customer dengan Short Flight maupun Long Flight memberikan score rata-rata yaitu teringgi pada score 3 dan 4
# - Untuk aspek food and drink customer dengan Short Flight maupun Long Flight cenderung memberikan rating merata pada score 2-5
# - Untuk aspek online boarding customer dengan Short Flight dan long Flight cenderung memberikan rating tinggi yaitu 4
# - Untuk aspek seat comfort customer dengan Short Flight maupun Long Flight cenderung memberikan rating tinggi yaitu 4
# - Untuk aspek inflight entertainment customer dengan Short Flight dan Long Flight cenderung memberikan rating tinggi yaitu 4
# - Untuk aspek on-board service customer dengan Short Flight dan Long Flight cenderung memberikan rating tinggi yaitu 4
# - Untuk aspek legroom service customer dengan Short Flight dan Long Flight cenderung memberikan rating tinggi yaitu 4
# - Untuk aspek baggage handling customer dengan Short Flight maupun Long Flight cenderung memberikan rating tinggi yaitu 4
# - Untuk aspek checkin service customer dengan Short Flight maupun Long Flight cenderung memberikan rating cukup tinggi yaitu 3 dan 4
# - Untuk aspek inflight service customer dengan Short Flight maupun Long Flight cenderung memberikan rating tinggi yaitu 4
# - Untuk aspek cleanliness customer dengan Short Flight maupun Long Flight cenderung memberikan rating tinggi yaitu 4

# %% [markdown]
# Summary
# - Secara keseluruhan, untuk customer dengan jarak perjalanan pendek (Short Flight) maupun panjang (Long Flight) sama sama memberikan nilai yang cukup rendah pada aspek Inflight Wifi Service
# - Untuk customer Short Flight memberikan nilai rata-rata pada aspek Ease of Online Booking dan Gate Location sedangkan aspek sisanya dinilai tinggi.
# - Sedangkan untuk customer Long Flight cenderung memberikan nilai tinggi kecuali pada Departure/Arrival Time Convenient, Ease of Online Booking dan Gate Location, yang mana nilainya tersebar merata

# %% [markdown]
# ## Summary dan Rekomendasi
# Setelah dilakukan analisa dan melihat pola-pola statistik, didapat kesimpulan dan rekomendasi untuk meningkatkan pelayanan menjadi lebih baik lagi.

# %% [markdown]
# ### Summary

# %% [markdown]
# 1. Apakah secara keseluruhan pelayanan yang diberikan oleh maskapai memuaskan?
#     - Secara keseluruhan penumpang maskapai cenderung netral atau tidak puas terhadap pelayanan yang diberikan, dengan persentase 56,7%
#
#     - Secara gender tidak ada beda yang terlihat signifikan baik dari distribusi proporsi customer maupun pemberian rating
#
#     - Secara jumlah Loyal Customer lebih banyak dibanding disloyal customer. Penilaian loyal customer kurang lebih sama antara netral/tidak puas dengan puas. Namun untuk disloyal customer, kebanyakan menilai netral/tidak puas
#
#     - Dari segment usia customer, didominasi oleh customer Prime Working Age atau usia antara 25 hingga 55 tahun. Penilaian yang diberikan oleh customer pada usia ini adalah sama antara netral/tidak puas dengan puas. Namun pada kelompok usia lain, didominasi dengan penilaian netral/tidak puas.
#
#     - Jika dilihat dari type of travel, penumpang dengan tujuan bisnis cenderung lebih banyak yang puas, sedangkan dengan tujuan personal travel lebih banyak yang netral/tidak puas
#
#     - Berdasarkan tipe kelas penerbangan, yang didominasi oleh kelas Business dan Economic, lebih banyak penumpang Business Class yang puas daripada yang netral/tidak puas. Sebaliknya untuk Economic Class dan Economic Plus Class lebih banyak penumpang yang netral/tidak puas daripada yang puas.
#
#     - Secara jarak tempuh penerbangan, penumpang yang menempuh jarak dibawah 3000 mil lebih banyak yang netral/tidak puas daripada yang puas, sedangkan untuk penumpang yang menempuh jarak diatas 3000 mil, lebih banyak yang puas. Titik balik dari kepuasan pelanggan dari segi jarak berada pada kisaran 1000 mil, dimana penumpang merasa lebih puas dengan pelayanan saat jarak tempuhnya diatas 1000 mil.
#
# 2. Faktor apa saja dalam pelayanan maskapai yang mempengaruhi kepuasan pelannggan?
#     - 3 faktor yang dinilai rendah oleh customer secara keseluruhan adalah:
#         - Gate location
#         - Ease of online booking
#         - Inflight wifi service
#     - 3 faktor dengan nilai terendah yang diberikan oleh customer yang netral/tidak puas adalah:
#         - Online boarding
#         - Ease of online booking
#         - Inflight wifi service
#     - 3 faktor dengan nilai tertinggi yang diberikan oleh customer yang puas adalah:
#         - Online boarding
#         - Inflight service
#         - Seat comfort
#
#     Online boarding menjadi faktor yang tidak konsisten. Kebanyakan customer yang menilai online boarding dengan nilai tinggi adalah Customer Loyal, dengan usia diatas 25 tahun dengan tujuan Bisnis dengan menggunakan kelas penerbangan Bisnis. Sedangkan untuk tipe customer yang menilai online boarding dengan nilai rata-rata bahkan rendah adalah customer disloyal, dengan usia dibawah 25 tahun untuk keperluan personal dengan tipe penerbangan ekonomi. Berdasarkan hal tersebut, bisa jadi penumpang yang menilai rendah adalah penumpang baru yang belum mengenal mekanisme online boarding atau penumpang dengan tingkat ekonomi yang kurang (dibuktikan dengan kelas yang diambil, meskipun perlu data lebih lanjut yang membuktikan tingkat ekonomi pelanggan)

# %% [markdown]
# ### Rekomendasi

# %% [markdown]
# 3. Dari sekian faktor tersebut, apakah pelayanan dapat dilanjutkan, ditambah/diimprovisasi, atau dieliminasi?
#     - Inflight service, baggage handling, dan seat comfort menjadi pelayanan yang mendapat rating cukup baik, sehingga konsistensi dan kualitas dari pelayanan ini dapat dipertahankan dan dilanjutkan
#     - Gate location, ease of online booking, inflight wifi service menjadi aspek yang rendah sehingga dibutuhkan improvisasi yang lebih mendalam
#     - Online boarding menjadi aspek yang dinilai rendah oleh sebagian segment namun dinilai tinggi juga oleh sebagian segment, sehingga perlu dilakukan improvisasi
#
# 4. Rekomendasi apa saja yang dapat diberikan kepada maskapai untuk dapat meningkatkan kepuasan pelanggan?
#     - Untuk meningkatkan rating penilaian yang diberikan kepada pelanggan, maskapai perlu mempertimbangkan untuk memilih gate location yang lebih dekat dengan pintu masuk bandara sehingga customer tidak perlu berjalan terlalu jauh untuk mencapai gate.
#     - Aspek online booking perlu dilakukan sosialisasi atau promosi yang lebih gencar lagi, guna untuk mengedukasi calon penumpang terkait mekanisme online booking atau bahkan evaluasi terkait UI/UX aplikasi pemesanan onlinenya
#     - Layanan wifi selama perjalanan perlu dilakukan evaluasi seperti memperbaiki kualitas koneksi, kemudahan akses dan sebagainya. layanan wifi menjadi perhatian karena hampir seluruh segment memberikan penilaian rata-rata bahkan cenderung rendah termasuk customer Business Class.
#     - Untuk layanan online boarding perlu ditingkatkan terkait sosialisasi atau bantuan kepada customer dengan segment-segment tertentu yang kurang memahami mekanisme dari online boarding, seperti pelanggan baru atau pelanggan yang literasi digitalnya kurang.
